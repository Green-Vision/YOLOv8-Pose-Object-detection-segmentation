# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import copy
from google.colab.patches import cv2_imshow

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 11670, done.
# remote: Counting objects: 100% (914/914), done.
# remote: Compressing objects: 100% (428/428), done.
# remote: Total 11670 (delta 591), reused 731 (delta 479), pack-reused 10756
# Receiving objects: 100% (11670/11670), 7.45 MiB | 20.95 MiB/s, done.
# Resolving deltas: 100% (7772/7772), done.

# %%
# %cd /content/ultralytics
# Out:
# /content/ultralytics

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !gdown https://drive.google.com/uc?id=16VsG-ppuHwKZwjybsPP9Z4Gg4vN-_mII

# %%
# !yolo task=detect mode=predict model=yolov8n.pt source="workOut.mp4"

# %%
from IPython.display import HTML
from base64 import b64encode
import os

# %%
path="/content/ultralytics/runs/detect/predict/workOut.avi"


# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {path} -vcodec libx264 {compressed_path}")
# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# !yolo task=segment mode=predict conf=0.25 source="workOut.mp4"

# %%
# !rm /content/result_compressed.mp4

# %%
path="/content/ultralytics/runs/segment/predict/workOut.avi"


# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {path} -vcodec libx264 {compressed_path}")
# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# !yolo task=pose mode=predict conf=0.25 source="workOut.mp4"

# %%
# !rm /content/result_compressed.mp4

# %%
path="/content/ultralytics/runs/pose/predict/workOut.avi"


# Compressed video path
compressed_path = "/content/result_compressed.mp4"

os.system(f"ffmpeg -i {path} -vcodec libx264 {compressed_path}")
# Show video
mp4 = open(compressed_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
